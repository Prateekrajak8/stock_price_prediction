# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
file_path = r'C:\Users\Prateek\Downloads\archive\Google_Stock_Price_Train.csv'
dataset_train = pd.read_csv(file_path)
training_set = dataset_train.iloc[:, 1:2].values

# %%
file_path = r'C:\Users\Prateek\Downloads\archive\Google_Stock_Price_Train.csv'
dataset_train = pd.read_csv(file_path)
training_set = dataset_train.iloc[:, 1:2].values
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0,1))
training_set_scaled = sc.fit_transform(training_set)

# %%
file_path = r'C:\Users\Prateek\Downloads\archive\Google_Stock_Price_Train.csv'
dataset_train = pd.read_csv(file_path)
training_set = dataset_train.iloc[:, 1:2].values
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0,1))
training_set_scaled = sc.fit_transform(training_set)
x_train = []
y_train = []
for i in range (60, 1258):
    x_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
x_train, y_train =  np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
# Out:
# WARNING:tensorflow:From C:\Users\Prateek\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3505, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Prateek\AppData\Local\Temp\ipykernel_14452\1652615228.py", line 1, in <module>
#     from tensorflow.keras.models import Sequential
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\keras\api\_v2\keras\__init__.py", line 3, in <module>
#     from keras.api._v2.keras import __internal__
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\keras\__init__.py", line 3, in <module>
#     from keras import __internal__
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\keras\__internal__\__init__.py", line 6, in <module>
#     from keras.__internal__ import models
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\keras\__internal__\models\__init__.py", line 3, in <module>
#     from keras.src.models.cloning import clone_and_build_model
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\keras\src\__init__.py", line 21, in <module>
#     from keras.src import applications
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\keras\src\applications\__init__.py", line 41, in <module>
#     from keras.src.applications.inception_resnet_v2 import InceptionResNetV2
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\keras\src\applications\inception_resnet_v2.py", line 324, in <module>
#     @keras.utils.register_keras_serializable()
#      ^^^^^^^^^^^
# AttributeError: partially initialized module 'keras.src' has no attribute 'utils' (most likely due to a circular import)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 2102, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 1310, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 1199, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 1052, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 978, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 878, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 712, in lines
#     return self._sd.lines
#            ^^^^^^^^^^^^^^
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\stack_data\core.py", line 698, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\stack_data\core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\stack_data\core.py", line 628, in executing_piece
#     return only(
#            ^^^^^
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\executing\executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
regressor = Sequential()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 regressor = Sequential()
#
# NameError: name 'Sequential' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
# file_path = 'C:\Users\Prateek\Downloads\archive\Google_Stock_Price_Train.csv'
dataset_train = pd.read_csv(Google_Stock_Price_Train.csv)
training_set = dataset_train.iloc[:, 1:2].values
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0, 1))
training_set_scaled = sc.fit_transform(training_set)
x_train = []
y_train = []
for i in range (60, 1258):
    x_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
x_train, y_train =  np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
# Initialize the Sequential model
regressor = Sequential()
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (x_train.shape[1], 1)))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))
regressor.add(Dense(units=1))
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
regressor.fit(x_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3505, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Prateek\AppData\Local\Temp\ipykernel_14452\443746528.py", line 4, in <module>
#     from tensorflow.keras.models import Sequential
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\keras\api\_v2\keras\__init__.py", line 3, in <module>
#     from keras.api._v2.keras import __internal__
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\keras\__init__.py", line 3, in <module>
#     from keras import __internal__
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\keras\__internal__\__init__.py", line 6, in <module>
#     from keras.__internal__ import models
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\keras\__internal__\models\__init__.py", line 3, in <module>
#     from keras.src.models.cloning import clone_and_build_model
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\keras\src\__init__.py", line 21, in <module>
#     from keras.src import applications
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\keras\src\applications\__init__.py", line 41, in <module>
#     from keras.src.applications.inception_resnet_v2 import InceptionResNetV2
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\keras\src\applications\inception_resnet_v2.py", line 324, in <module>
#     @keras.utils.register_keras_serializable()
#      ^^^^^^^^^^^
# AttributeError: partially initialized module 'keras.src' has no attribute 'utils' (most likely due to a circular import)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 2102, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 1310, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 1199, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 1052, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 978, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 878, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 712, in lines
#     return self._sd.lines
#            ^^^^^^^^^^^^^^
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\stack_data\core.py", line 698, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\stack_data\core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\stack_data\core.py", line 628, in executing_piece
#     return only(
#            ^^^^^
#   File "C:\Users\Prateek\anaconda3\Lib\site-packages\executing\executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (x_train.shape[1], 1)))
regressor.add(Dropout(0.2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (x_train.shape[1], 1)))
#       2 regressor.add(Dropout(0.2))
#
# NameError: name 'regressor' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 regressor.fit(x_train, y_train, epochs = 100, batch_size = 32)
#
# NameError: name 'regressor' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
# file_path = 'C:\Users\Prateek\Downloads\archive\Google_Stock_Price_Train.csv'
dataset_train = pd.read_csv('Google_Stock_Price_Train.csv')
training_set = dataset_train.iloc[:, 1:2].values
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0, 1))
training_set_scaled = sc.fit_transform(training_set)
x_train = []
y_train = []
for i in range (60, 1258):
    x_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
x_train, y_train =  np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
# Initialize the Sequential model
regressor = Sequential()
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (x_train.shape[1], 1)))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))
regressor.add(Dense(units=1))
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
regressor.fit(x_train, y_train, epochs = 100, batch_size = 32)
dataset_total = pd.conact((dataset_train['Open'], dataset_test['Open']), axis = 0)
inputs - dataset_total[len(dataset_total)-len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs =  sc.transform(inputs)
x_test = []
for i in range(60, 80):
    x_test.append(inputs[i-60:i,0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
predicted_stock_price = regressor.predict(x_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
dataset_total = pd.concat((dataset_train['Open'], dataset_test['Open']), axis = 0)
inputs - dataset_total[len(dataset_total)-len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs =  sc.transform(inputs)
x_test = []
for i in range(60, 80):
    x_test.append(inputs[i-60:i,0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
predicted_stock_price = regressor.predict(x_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 22s 157ms/step - loss: 0.0371
# Epoch 2/100
# 38/38 [==============================] - 6s 153ms/step - loss: 0.0064
# Epoch 3/100
# 38/38 [==============================] - 5s 142ms/step - loss: 0.0050
# Epoch 4/100
# 38/38 [==============================] - 5s 135ms/step - loss: 0.0052
# Epoch 5/100
# 38/38 [==============================] - 6s 145ms/step - loss: 0.0047
# Epoch 6/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.0045
# Epoch 7/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0043
# Epoch 8/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0045
# Epoch 9/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0049
# Epoch 10/100
# 38/38 [==============================] - 5s 135ms/step - loss: 0.0043
# Epoch 11/100
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0041
# Epoch 12/100
# 38/38 [==============================] - 5s 142ms/step - loss: 0.0046
# Epoch 13/100
# 38/38 [==============================] - 5s 133ms/step - loss: 0.0045
# Epoch 14/100
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0046
# Epoch 15/100
# 38/38 [==============================] - 5s 140ms/step - loss: 0.0040
# Epoch 16/100
# 38/38 [==============================] - 5s 127ms/step - loss: 0.0039
# Epoch 17/100
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0040
# Epoch 18/100
# 38/38 [==============================] - 5s 142ms/step - loss: 0.0039
# Epoch 19/100
# 38/38 [==============================] - 5s 136ms/step - loss: 0.0035
# Epoch 20/100
# 38/38 [==============================] - 5s 132ms/step - loss: 0.0039
# Epoch 21/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0041
# Epoch 22/100
# 38/38 [==============================] - 5s 134ms/step - loss: 0.0035
# Epoch 23/100
# 38/38 [==============================] - 5s 133ms/step - loss: 0.0034
# Epoch 24/100
# 38/38 [==============================] - 6s 147ms/step - loss: 0.0035
# Epoch 25/100
# 38/38 [==============================] - 5s 134ms/step - loss: 0.0038
# Epoch 26/100
# 38/38 [==============================] - 5s 131ms/step - loss: 0.0036
# Epoch 27/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0030
# Epoch 28/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0030
# Epoch 29/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0029
# Epoch 30/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0029
# Epoch 31/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0028
# Epoch 32/100
# 38/38 [==============================] - 5s 127ms/step - loss: 0.0030
# Epoch 33/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0029
# Epoch 34/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0032
# Epoch 35/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0027
# Epoch 36/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.0027
# Epoch 37/100
# 38/38 [==============================] - 5s 142ms/step - loss: 0.0027
# Epoch 38/100
# 38/38 [==============================] - 5s 135ms/step - loss: 0.0027
# Epoch 39/100
# 38/38 [==============================] - 6s 146ms/step - loss: 0.0027
# Epoch 40/100
# 38/38 [==============================] - 5s 142ms/step - loss: 0.0031
# Epoch 41/100
# 38/38 [==============================] - 5s 118ms/step - loss: 0.0027
# Epoch 42/100
# 38/38 [==============================] - 6s 145ms/step - loss: 0.0026
# Epoch 43/100
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0025
# Epoch 44/100
# 38/38 [==============================] - 5s 134ms/step - loss: 0.0023
# Epoch 45/100
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0024
# Epoch 46/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0026
# Epoch 47/100
# 38/38 [==============================] - 5s 135ms/step - loss: 0.0030
# Epoch 48/100
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0025
# Epoch 49/100
# 38/38 [==============================] - 5s 140ms/step - loss: 0.0024
# Epoch 50/100
# 38/38 [==============================] - 5s 130ms/step - loss: 0.0025
# Epoch 51/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0023
# Epoch 52/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0021
# Epoch 53/100
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0022
# Epoch 54/100
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0022
# Epoch 55/100
# 38/38 [==============================] - 5s 142ms/step - loss: 0.0023
# Epoch 56/100
# 38/38 [==============================] - 5s 129ms/step - loss: 0.0022
# Epoch 57/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0022
# Epoch 58/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0022
# Epoch 59/100
# 38/38 [==============================] - 5s 136ms/step - loss: 0.0022
# Epoch 60/100
# 38/38 [==============================] - 5s 132ms/step - loss: 0.0020
# Epoch 61/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.0020
# Epoch 62/100
# 38/38 [==============================] - 6s 151ms/step - loss: 0.0022
# Epoch 63/100
# 38/38 [==============================] - 5s 136ms/step - loss: 0.0022
# Epoch 64/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0020
# Epoch 65/100
# 38/38 [==============================] - 5s 132ms/step - loss: 0.0018
# Epoch 66/100
# 38/38 [==============================] - 5s 134ms/step - loss: 0.0020
# Epoch 67/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0023
# Epoch 68/100
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0019
# Epoch 69/100
# 38/38 [==============================] - 5s 125ms/step - loss: 0.0018
# Epoch 70/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0019
# Epoch 71/100
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0019
# Epoch 72/100
# 38/38 [==============================] - 5s 130ms/step - loss: 0.0022
# Epoch 73/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.0020
# Epoch 74/100
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0018
# Epoch 75/100
# 38/38 [==============================] - 5s 136ms/step - loss: 0.0018
# Epoch 76/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0018
# Epoch 77/100
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0017
# Epoch 78/100
# 38/38 [==============================] - 5s 134ms/step - loss: 0.0017
# Epoch 79/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0017
# Epoch 80/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0017
# Epoch 81/100
# 38/38 [==============================] - 5s 129ms/step - loss: 0.0017
# Epoch 82/100
# 38/38 [==============================] - 5s 140ms/step - loss: 0.0016
# Epoch 83/100
# 38/38 [==============================] - 5s 140ms/step - loss: 0.0016
# Epoch 84/100
# 38/38 [==============================] - 5s 132ms/step - loss: 0.0016
# Epoch 85/100
# 38/38 [==============================] - 5s 140ms/step - loss: 0.0016
# Epoch 86/100
# 38/38 [==============================] - 5s 142ms/step - loss: 0.0016
# Epoch 87/100
# 38/38 [==============================] - 5s 130ms/step - loss: 0.0016
# Epoch 88/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0016
# Epoch 89/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0014
# Epoch 90/100
# 38/38 [==============================] - 5s 133ms/step - loss: 0.0016
# Epoch 91/100
# 38/38 [==============================] - 5s 140ms/step - loss: 0.0016
# Epoch 92/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0016
# Epoch 93/100
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0015
# Epoch 94/100
# 38/38 [==============================] - 5s 140ms/step - loss: 0.0018
# Epoch 95/100
# 38/38 [==============================] - 5s 142ms/step - loss: 0.0018
# Epoch 96/100
# 38/38 [==============================] - 5s 129ms/step - loss: 0.0014
# Epoch 97/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0015
# Epoch 98/100
# 35/38 [==========================>...] - ETA: 0s - loss: 0.0015

# %%
dataset_total = pd.concat((dataset_train['Open'], dataset_test['Open']), axis = 0)
inputs - dataset_total[len(dataset_total)-len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs =  sc.transform(inputs)
x_test = []
for i in range(60, 80):
    x_test.append(inputs[i-60:i,0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
predicted_stock_price = regressor.predict(x_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 dataset_total = pd.concat((dataset_train['Open'], dataset_test['Open']), axis = 0)
#       2 inputs - dataset_total[len(dataset_total)-len(dataset_test) - 60:].values
#       3 inputs = inputs.reshape(-1,1)
#
# NameError: name 'dataset_test' is not defined
